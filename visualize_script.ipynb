# %%
from script_analyzer import TranscriptAnalyzer

# %%
cur_analyzer = TranscriptAnalyzer("le1n8lJCGKw_concatenated.json")
cur_analyzer.plot_top_words(top_n=175, start_n=0)

# %%
cur_analyzer = TranscriptAnalyzer("generated_script_20260403_221600.json")
cur_analyzer.plot_top_words(top_n=100, start_n=0)
